# %%
# NRC/Telegraaf comparison between Nexis and web search

import csv

medium = ""
datum = ""
kop = ""
duplicate = 0
firstrow = ["Medium", "Datum", "Kop"]

with open('Telegraaf unique.csv', 'w', newline='', encoding="utf-8") as f:
    writer = csv.writer(f, delimiter = ";")
    writer.writerow(firstrow)

# Define writer
def csv_add(row):
    with open('Telegraaf unique.csv', 'a', newline='', encoding="utf-8") as f:
        writer = csv.writer(f, delimiter = ";")
        writer.writerow(row)

print("checking regular search.")
with open('Telegraaf regular.csv', 'r', encoding="utf-8") as x:
    data = csv.reader(x, delimiter=';', quotechar='|')
    for row in data:
        medium = row[0]
        datum = row[1]
        kop = row[2]
        duplicate = 0

        with open('Telegraaf nexis.csv', 'r', encoding="utf-8") as x:
            data2 = csv.reader(x, delimiter=';', quotechar='|')
            for row2 in data2:
                # Check if same
                if row2[2] == row[2]:
                    duplicate += 1
                elif row2[1] == row[1]:
                    if Levenshtein.distance(row2[2], row[2]) < 5:
                        print(row, row2)
                        duplicate += 1
        if duplicate == 0:
            nextrow = [medium, datum, kop]
            csv_add(nextrow)

print("checking nexis.")
with open('Telegraaf nexis.csv', 'r', encoding="utf-8") as x:
    data = csv.reader(x, delimiter=';', quotechar='|')
    for row in data:
        medium = row[0]
        datum = row[1]
        kop = row[2]
        duplicate = 0

        with open('Telegraaf regular.csv', 'r', encoding="utf-8") as x:
            data2 = csv.reader(x, delimiter=';', quotechar='|')
            for row2 in data2:
                # Check if same
                if row2[2] == row[2]:
                    duplicate += 1
                elif row2[1] == row[1]:
                    if Levenshtein.distance(row2[2], row[2]) < 5:
                        print(row, row2)
                        duplicate += 1
        if duplicate == 0:
            nextrow = [medium, datum, kop]
            csv_add(nextrow)
            
print("Done.")
# Out:
# checking regular search.
# ['Telegraaf', '28/10/2020', "'Impact coronavirus beperkt zichtbaar in cijfers ziekteverzuim'"] ['Telegraaf Nexis', '28/10/2020', "Impact coronavirus beperkt zichtbaar in cijfers ziekteverzuim'"]
# ['Telegraaf', '30/10/2020', 'Kylie Minogue mist familie: ’De tijd doet raar’'] ['Telegraaf Nexis', '30/10/2020', 'Kylie Minoque mist familie: ’De tijd doet raar’']
# ['Telegraaf', '05/11/2020', 'Pathé biedt dagelijks gratis film aan tijdens lockdown'] ['Telegraaf Nexis', '05/11/2020', 'Pathé biedt dageljks gratis film aan tijdens lockdown']
# ['Telegraaf', '30/11/2020', 'Damien (8) ligt op ic: ’Wie denkt dat corona onzin is, kijk dan naar mijn zoontje’'] ['Telegraaf Nexis', '30/11/2020', 'Damien (6) ligt op ic: ’Wie denkt dat corona onzin is, kijk dan naar mijn zoontje’']
# ['Telegraaf', '02/12/2020', 'Coronavaccin vanaf volgende week beschikbaar in VK'] ['Telegraaf Nexis', '02/12/2020', '’Coronavaccin vanaf volgende week beschikbaar in VK’']
# ...

# %%
# Give Pattern scores for unique headlines

import csv
from pattern.nl import sentiment

medium = ""
datum = ""
kop = ""

with open('Telegraaf unique Pattern.csv', 'w', newline='', encoding="utf-8") as f:
    writer = csv.writer(f, delimiter = ";")
    writer.writerow(firstrow)

# Define writer
def csv_add(row):
    with open('Telegraaf unique Pattern.csv', 'a', newline='', encoding="utf-8") as f:
        writer = csv.writer(f, delimiter = ";")
        writer.writerow(row)
        
with open('Telegraaf unique.csv', 'r', encoding="utf-8") as x:
    data = csv.reader(x, delimiter=';', quotechar='|')
    for row in data:
        medium = row[0]
        datum = row[1]
        kop = row[2]
        score = sentiment(kop)
        pattern = str(score).split(",")[0].replace("(","")
        nextrow = [medium, datum, kop, pattern]
        csv_add(nextrow)
        
print("Done.")
# Out:
# Done.
